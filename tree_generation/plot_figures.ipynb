# %%
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt

# %%
result_folder = Path("../results/processed/")
output_fpath = result_folder / Path("coalescence_sackin_mixed.pkl")

# %%
df = pd.read_pickle(output_fpath)
# Out:
#     graph_type  rep  mean_coalescence_time  variance_coalescence_time  \
# 0           BA    0                   0.23                     0.0221
# 1           BA    1                   0.11                     0.0109
# 2           BA    2                   0.21                     0.0129
# 3           BA    3                   0.18                     0.0156
# 4           BA    4                   0.23                     0.0281
# ..         ...  ...                    ...                        ...
# 115         WS   25                   0.20                     0.0220
# 116         WS   26                   0.27                     0.0161
# 117         WS   27                   0.18                     0.0136
# 118         WS   28                   0.23                     0.0201
# 119         WS   29                   0.23                     0.0201
#
#        sackin  sackin_variance        Js   variance_Js
# 0    0.022366         0.000005  0.009268  5.479237e-07
# ...
